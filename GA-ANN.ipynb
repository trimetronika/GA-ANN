# %% [markdown]
# ## 1. Import Libraries dan Setup
# Mengimpor pustaka yang diperlukan dan mengatur seed untuk reproduktibilitas.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import LearningRateScheduler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import TimeSeriesSplit
import matplotlib.pyplot as plt
import seaborn as sns
from deap import base, creator, tools, algorithms
import random
import warnings
import os
warnings.filterwarnings('ignore')

# Set seed untuk reproduktibilitas
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# %matplotlib inline

# %% [markdown]
# ## 2. Definisi Parameter Eksperimen
# Mendefinisikan semua parameter yang akan digunakan dalam eksperimen.

# %%
# Parameter data
INPUT_FILE = 'data/raw/data_jkse_eda_final.csv'
WINDOW_SIZE = 3
N_SPLITS = 4

# Parameter Algoritma Genetika (GA)
POPULATION_SIZE = 50
GENERATIONS = 100
CROSSOVER_PROB = 0.8
MUTATION_PROB = 0.01
MUTATION_SIGMA = 0.2
TOURNAMENT_SIZE = 4

# Parameter ANN
HIDDEN_NEURONS = 7
LEARNING_RATE = 0.001
INPUT_DIM = 3
DROPOUT_RATE = 0.3
L2_LAMBDA = 0.005

# Parameter pelatihan
EPOCHS = 100
BATCH_SIZE = 32
EARLY_STOP_PATIENCE = 5

# Hitung jumlah bobot untuk GA
WEIGHT_COUNT = (INPUT_DIM * HIDDEN_NEURONS +  # W1
                HIDDEN_NEURONS +              # b1
                HIDDEN_NEURONS +              # W2
                1)                            # b2

# %% [markdown]
# ## 3. Fungsi Utilitas
# Mendefinisikan fungsi utilitas yang diperlukan untuk pelatihan, evaluasi, dan visualisasi.

# %%
def lr_scheduler(epoch, lr):
    """Scheduler untuk mengurangi learning rate setelah 50 epoch."""
    if epoch > 50:
        return lr * 0.95 ** ((epoch - 50) // 20)
    return lr

def build_ann_model(input_dim, hidden_neurons, use_dropout=False, use_l2=False):
    """Membangun model ANN dengan parameter yang diberikan."""
    initializer = 'glorot_uniform'
    model = Sequential([
        Dense(hidden_neurons, input_dim=input_dim, activation='relu',
              kernel_initializer=initializer,
              kernel_regularizer=tf.keras.regularizers.l2(L2_LAMBDA) if use_l2 else None),
        Dropout(DROPOUT_RATE) if use_dropout else tf.keras.layers.Lambda(lambda x: x),
        Dense(1, activation='linear',
              kernel_regularizer=tf.keras.regularizers.l2(L2_LAMBDA) if use_l2 else None)
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                  loss='mse')
    return model

def set_model_weights(model, weights):
    """Mengatur bobot model dari vektor weights untuk GA."""
    w1_size = INPUT_DIM * HIDDEN_NEURONS
    w1 = np.array(weights[:w1_size]).reshape(INPUT_DIM, HIDDEN_NEURONS)
    b1 = np.array(weights[w1_size:w1_size + HIDDEN_NEURONS])
    w2 = np.array(weights[w1_size + HIDDEN_NEURONS:w1_size + 2 * HIDDEN_NEURONS]).reshape(HIDDEN_NEURONS, 1)
    b2 = np.array([weights[-1]])
    model.layers[0].set_weights([w1, b1])
    model.layers[2].set_weights([w2, b2])

def evaluate_individual(individual, model, X, y):
    """Menghitung fitness individu berdasarkan RMSE untuk GA."""
    set_model_weights(model, individual)
    predictions = model.predict(X, verbose=0).flatten()
    mse = mean_squared_error(y, predictions)
    rmse = np.sqrt(mse)
    return (1.0 / (rmse + 1e-10),)

def calculate_metrics(y_true, y_pred):
    """Menghitung metrik evaluasi (RMSE, MAE, MAPE)."""
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100
    return rmse, mae, mape

def denormalize(data, min_val, max_val):
    """Mendenormalisasi data dari [0, 1] ke skala asli."""
    return data * (max_val - min_val) + min_val

def glorot_init(input_dim, hidden_neurons):
    """Membuat inisialisasi bobot dengan rentang Glorot untuk GA."""
    limit_w1 = np.sqrt(6 / (input_dim + hidden_neurons))
    limit_w2 = np.sqrt(6 / (hidden_neurons + 1))
    weights = []
    for _ in range(input_dim * hidden_neurons):
        weights.append(random.uniform(-limit_w1, limit_w1))
    for _ in range(hidden_neurons):
        weights.append(0.0)
    for _ in range(hidden_neurons):
        weights.append(random.uniform(-limit_w2, limit_w2))
    weights.append(0.0)
    return weights

# %% [markdown]
# ## 4. Load dan Persiapan Data
# Memuat data IHSG, normalisasi, dan membuat sliding window.

# %%
# Load data
df = pd.read_csv(INPUT_FILE, parse_dates=['Date'])
df.sort_values('Date', inplace=True)
dates = df['Date'].values
close_values = df['Close'].values
close_min = close_values.min()
close_max = close_values.max()
close_normalized = (close_values - close_min) / (close_max - close_min)

# Visualisasi data awal
plt.figure(figsize=(14, 6))
plt.plot(dates, close_values, label='Harga Penutupan (Close)', color='blue')
plt.title('Harga Penutupan IHSG (Data Awal)')
plt.xlabel('Tanggal')
plt.ylabel('Harga Penutupan')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('ihsg_data_initial.png')
plt.show()

# Buat sliding window
X, y = [], []
for i in range(len(close_normalized) - WINDOW_SIZE):
    X.append(close_normalized[i:i + WINDOW_SIZE])
    y.append(close_normalized[i + WINDOW_SIZE])
X = np.array(X)
y = np.array(y)
dates = dates[WINDOW_SIZE:]
close_values = close_values[WINDOW_SIZE:]
print(f"Ukuran fitur X: {X.shape}")
print(f"Ukuran target y: {y.shape}")

# Buat pembagian fold dengan TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=N_SPLITS)
for fold, (train_idx, test_idx) in enumerate(tscv.split(X), 1):
    train_dates = dates[train_idx]
    test_dates = dates[test_idx]
    train_close = close_values[train_idx]
    test_close = close_values[test_idx]
    
    plt.figure(figsize=(14, 6))
    plt.plot(dates, close_values, color='gray', alpha=0.3, label='Semua Data')
    plt.plot(train_dates, train_close, color='blue', label=f'Fold {fold} - Latih')
    plt.plot(test_dates, test_close, color='red', label=f'Fold {fold} - Uji')
    plt.title(f'Pembagian Data IHSG - Fold {fold} (TimeSeriesSplit)')
    plt.xlabel('Tanggal')
    plt.ylabel('Harga Penutupan')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(f'ihsg_fold_{fold}_split.png')
    plt.show()
# Out:
# Ukuran fitur X: (779, 3)
# Ukuran target y: (779,)

# %% [markdown]
# ## 5. Setup dan Pelatihan GANN per Fold
# Menggunakan Algoritma Genetika (mengunakan library DEAP) untuk mengoptimalkan bobot ANN tanpa pelatihan lanjutan.

# %%
# Bagian 6: Pelatihan GANN per Fold
# Inisialisasi untuk menyimpan hasil
gann_metrics = []
gann_predictions_per_fold = []
gann_best_weights = []

# Setup GA untuk GANN
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register("attr_float", glorot_init, INPUT_DIM, HIDDEN_NEURONS)
toolbox.register("individual", tools.initIterate, creator.Individual, toolbox.attr_float)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=MUTATION_SIGMA, indpb=MUTATION_PROB)
# toolbox.register("select", tools.selRoulette)
toolbox.register("select", tools.selTournament, tournsize=TOURNAMENT_SIZE)

# Buat direktori untuk menyimpan model jika belum ada
os.makedirs('models', exist_ok=True)

# Loop untuk setiap fold
for fold, (train_idx, test_idx) in enumerate(tscv.split(X), 1):
    print(f"\n=== Melatih GANN Fold {fold} ===")
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    train_close = close_values[train_idx]
    test_close = close_values[test_idx]
    train_dates = dates[train_idx]
    test_dates = dates[test_idx]

    # Buat model untuk GA
    model = build_ann_model(INPUT_DIM, HIDDEN_NEURONS, use_dropout=False, use_l2=False)

    # Register fungsi evaluasi
    toolbox.register("evaluate", evaluate_individual, model=model, X=X_train, y=y_train)

    # Jalankan GA
    population = toolbox.population(n=POPULATION_SIZE)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("avg", np.mean)
    stats.register("max", np.max)
    hof = tools.HallOfFame(1)

    # List untuk menyimpan fitness per generasi
    fitness_avg_history = []
    fitness_max_history = []

    for gen in range(GENERATIONS):
        population = algorithms.varAnd(population, toolbox, cxpb=CROSSOVER_PROB, mutpb=MUTATION_PROB)
        invalid_ind = [ind for ind in population if not ind.fitness.valid]
        fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit
        hof.update(population)
        population = toolbox.select(population, len(population))
        record = stats.compile(population)
        fitness_avg_history.append(record['avg'])
        fitness_max_history.append(record['max'])
        print(f"Generasi {gen + 1}: Rata-rata Fitness (1/RMSE) = {record['avg']:.6f}, Maksimum Fitness (1/RMSE) = {record['max']:.6f}")

    # Visualisasi kurva fitness
    plt.figure(figsize=(10, 5))
    plt.plot(range(1, GENERATIONS + 1), fitness_avg_history, label='Rata-rata Fitness (1/RMSE)', color='blue')
    plt.plot(range(1, GENERATIONS + 1), fitness_max_history, label='Maksimum Fitness (1/RMSE)', color='red')
    plt.title(f'Kurva Fitness selama Generasi GA - GANN (Fold {fold}, Glorot Init)')
    plt.xlabel('Generasi')
    plt.ylabel('Fitness (1/RMSE)')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f'ihsg_fitness_curve_gann_fold_{fold}_glorot.png')
    plt.show()

    best_weights = hof[0]
    gann_best_weights.append(best_weights)

    # Prediksi
    set_model_weights(model, best_weights)
    gann_predictions = model.predict(np.concatenate([X_train, X_test]), verbose=0).flatten()
    gann_predictions_denorm = denormalize(gann_predictions, close_min, close_max)

    # Simpan model
    model.save(f'models/gann_fold_{fold}.keras')

    # Simpan prediksi
    fold_pred_df = pd.DataFrame({
        'Fold': fold,
        'Date': np.concatenate([train_dates, test_dates]),
        'Actual_Close': np.concatenate([train_close, test_close]),
        'Predicted_GANN': gann_predictions_denorm,
        'Data': ['Latih'] * len(train_dates) + ['Uji'] * len(test_dates)
    })
    gann_predictions_per_fold.append(fold_pred_df)

    # Bersihkan memori
    import gc
    gc.collect()
    tf.keras.backend.clear_session()
# Out:
# === Melatih GANN Fold 1 ===
# Generasi 1: Rata-rata Fitness (1/RMSE) = 5.952439, Maksimum Fitness (1/RMSE) = 18.007383
# Generasi 2: Rata-rata Fitness (1/RMSE) = 13.029453, Maksimum Fitness (1/RMSE) = 26.123321
# Generasi 3: Rata-rata Fitness (1/RMSE) = 14.841506, Maksimum Fitness (1/RMSE) = 26.123321
Maksimum Fitness (1/RMSE) = 34.496716
# Generasi 57: Rata-rata Fitness (1/RMSE) = 34.496716, Maksimum Fitness (1/RMSE) = 34.496716
# Generasi 58: Rata-rata Fitness (1/RMSE) = 34.496716, Maksimum Fitness (1/RMSE) = 34.496716
# Generasi 59: Rata-rata Fitness (1/RMSE) = 34.496716, Maksimum Fitness (1/RMSE) = 34.496716
# Generasi 60: Rata-rata Fitness (1/RMSE) = 34.496716, Maksimum Fitness (1/RMSE) = 34.496716
# Generasi 61: Rata-rata Fitness (1/RMSE) = 34.509837, Maksimum Fitness (1/RMSE) = 34.551388
# Generasi 62: Rata-rata Fitness (1/RMSE) = 34.560071, Maksimum Fitness (1/RMSE) = 34.920143
# Generasi 63: Rata-rata Fitness (1/RMSE) = 34.571577, Maksimum Fitness (1/RMSE) = 34.920143
# Generasi 64: Rata-rata Fitness (1/RMSE) = 34.598619, Maksimum Fitness (1/RMSE) = 34.920143
# Generasi 65: Rata-rata Fitness (1/RMSE) = 34.699071, Maksimum Fitness (1/RMSE) = 34.920143
# Generasi 66: Rata-rata Fitness (1/RMSE) = 34.837241, Maksimum Fitness (1/RMSE) = 34.920143
# Generasi 67: Rata-rata Fitness (1/RMSE) = 34.920143, Maksimum Fitness (1/RMSE) = 34.920143
# Generasi 68: Rata-rata Fitness (1/RMSE) = 34.920143, Maksimum Fitness (1/RMSE) = 34.920143
# Generasi 69: Rata-rata Fitness (1/RMSE) = 34.920143, Maksimum Fitness (1/RMSE) = 34.920143
# Generasi 70: Rata-rata Fitness (1/RMSE) = 34.920143, Maksimum Fitness (1/RMSE) = 34.920143
# Generasi 71: Rata-rata Fitness (1/RMSE) = 34.920143, Maksimum Fitness (1/RMSE) = 34.920143
# Generasi 72: Rata-rata Fitness (1/RMSE) = 34.920143, Maksimum Fitness (1/RMSE) = 34.920143
# Generasi 73: Rata-rata Fitness (1/RMSE) = 34.920143, Maksimum Fitness (1/RMSE) = 34.920143
# Generasi 74: Rata-rata Fitness (1/RMSE) = 34.920144, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 75: Rata-rata Fitness (1/RMSE) = 34.920147, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 76: Rata-rata Fitness (1/RMSE) = 34.920156, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 77: Rata-rata Fitness (1/RMSE) = 34.920169, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 78: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 79: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 80: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 81: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 82: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 83: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 84: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 85: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 86: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 87: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 88: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 89: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 90: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 91: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 92: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 93: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 94: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 95: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 96: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 97: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 98: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 99: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# Generasi 100: Rata-rata Fitness (1/RMSE) = 34.920174, Maksimum Fitness (1/RMSE) = 34.920174
# === Melatih GANN Fold 4 ===
# Generasi 1: Rata-rata Fitness (1/RMSE) = 9.256115, Maksimum Fitness (1/RMSE) = 28.236129
# Generasi 2: Rata-rata Fitness (1/RMSE) = 14.825205, Maksimum Fitness (1/RMSE) = 28.236129
# Generasi 3: Rata-rata Fitness (1/RMSE) = 20.017266, Maksimum Fitness (1/RMSE) = 30.085036
# Generasi 4: Rata-rata Fitness (1/RMSE) = 24.656363, Maksimum Fitness (1/RMSE) = 30.085036
# Generasi 5: Rata-rata Fitness (1/RMSE) = 27.701815, Maksimum Fitness (1/RMSE) = 30.085036
# Generasi 6: Rata-rata Fitness (1/RMSE) = 29.438965, Maksimum Fitness (1/RMSE) = 30.245963
# Generasi 7: Rata-rata Fitness (1/RMSE) = 29.907308, Maksimum Fitness (1/RMSE) = 30.245963
# Generasi 8: Rata-rata Fitness (1/RMSE) = 30.234344, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 9: Rata-rata Fitness (1/RMSE) = 30.391653, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 10: Rata-rata Fitness (1/RMSE) = 30.634327, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 11: Rata-rata Fitness (1/RMSE) = 30.789672, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 12: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 13: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 14: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 15: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 16: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 17: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 18: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 19: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 20: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 21: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 22: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 23: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 24: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 25: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 26: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 27: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 28: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 29: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 30: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 31: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 32: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 33: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 34: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 35: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 36: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 37: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 38: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 39: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 40: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 41: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 42: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 43: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 44: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 45: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 46: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 47: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 48: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 49: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 50: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 51: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 52: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 53: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 54: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 55: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 56: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 57: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 58: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 59: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 60: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 61: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 62: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 63: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 64: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 65: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 66: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 67: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 68: Rata-rata Fitness (1/RMSE) = 30.800768, Maksimum Fitness (1/RMSE) = 30.800768
# Generasi 69: Rata-rata Fitness (1/RMSE) = 30.816378, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 70: Rata-rata Fitness (1/RMSE) = 30.843695, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 71: Rata-rata Fitness (1/RMSE) = 30.929550, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 72: Rata-rata Fitness (1/RMSE) = 30.984185, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 73: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 74: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 75: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 76: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 77: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 78: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 79: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 80: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 81: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 82: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 83: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 84: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 85: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 86: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 87: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 88: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 89: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 90: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 91: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 92: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 93: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 94: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 95: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 96: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 97: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 98: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 99: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893
# Generasi 100: Rata-rata Fitness (1/RMSE) = 30.995893, Maksimum Fitness (1/RMSE) = 30.995893

# %% [markdown]
# #### Penggunaan `gc.collect()` untuk Mengatasi Masalah Memori
#
# Dalam proses pelatihan model pada kode ini, pernah terjadi masalah di mana proses terhenti (stuck) saat menjalankan pelatihan dengan 150 generasi, terutama karena penggunaan memori backend yang sangat besar oleh TensorFlow/Keras. Untuk mengatasi masalah ini, fungsi `gc.collect()` dari modul `gc` (garbage collector) Python digunakan untuk membersihkan memori secara manual setelah setiap fold selesai diproses.
#
# Fungsi `gc.collect()` bekerja dengan membebaskan memori dari objek yang tidak lagi memiliki referensi aktif, seperti array sementara atau model yang sudah tidak digunakan. Namun, penggunaan `gc.collect()` ini **tidak memengaruhi referensi atau variabel aktif** seperti `fold_pred_df`, yang disimpan dalam list seperti `gann_predictions_per_fold`, `gadam_predictions_per_fold`, dan `adam_predictions_per_fold`. Dengan demikian, data penting tetap aman, sementara memori yang tidak diperlukan dapat dibersihkan untuk mencegah kebocoran memori (memory leak), memastikan proses pelatihan berjalan lancar hingga selesai, bahkan untuk konfigurasi dengan 150 generasi.

# %% [markdown]
# ## 6. Validasi GANN per Fold
# Mengevaluasi performa GANN pada setiap fold dan membuat visualisasi.

# %%
for fold, (train_idx, test_idx) in enumerate(tscv.split(X), 1):
    print(f"\n=== Validasi GANN Fold {fold} ===")
    train_close = close_values[train_idx]
    test_close = close_values[test_idx]
    train_dates = dates[train_idx]
    test_dates = dates[test_idx]

    # Ambil prediksi
    fold_pred_df = gann_predictions_per_fold[fold-1]
    gann_pred = fold_pred_df['Predicted_GANN'].values
    train_pred = gann_pred[:len(train_close)]
    test_pred = gann_pred[len(train_close):]

    # Hitung metrik
    rmse_train, mae_train, mape_train = calculate_metrics(train_close, train_pred)
    rmse_test, mae_test, mape_test = calculate_metrics(test_close, test_pred)
    gann_metrics.append({'Fold': fold, 'Data': 'Latih', 'RMSE': rmse_train, 'MAE': mae_train, 'MAPE': mape_train})
    gann_metrics.append({'Fold': fold, 'Data': 'Uji', 'RMSE': rmse_test, 'MAE': mae_test, 'MAPE': mape_test})

    # Visualisasi prediksi vs aktual
    plt.figure(figsize=(14, 6))
    plt.plot(train_dates, train_close, label='Aktual (Latih)', color='blue', alpha=0.5)
    plt.plot(train_dates, train_pred, label='GANN (Latih)', color='red')
    plt.plot(test_dates, test_close, label='Aktual (Uji)', color='green', alpha=0.5)
    plt.plot(test_dates, test_pred, label='GANN (Uji)', color='orange')
    plt.title(f'Prediksi Harga IHSG dengan GANN - Fold {fold}')
    plt.xlabel('Tanggal')
    plt.ylabel('Harga Penutupan')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(f'ihsg_prediction_gann_fold_{fold}_glorot.png')
    plt.show()
# Out:
# === Validasi GANN Fold 1 ===
# === Validasi GANN Fold 2 ===
# === Validasi GANN Fold 3 ===
# === Validasi GANN Fold 4 ===

# %% [markdown]
# ## 7. Setup dan Pelatihan GADAM per Fold
# Menggunakan Algoritma Genetika (mengunakan library DEAP) untuk mengoptimalkan bobot awal, kemudian melatih dengan ADAM.

# %%
# Inisialisasi untuk menyimpan hasil
gadam_metrics = []
gadam_predictions_per_fold = []
gadam_best_weights = []
gadam_history = []

# Setup GA untuk GADAM
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register("attr_float", glorot_init, INPUT_DIM, HIDDEN_NEURONS)
toolbox.register("individual", tools.initIterate, creator.Individual, toolbox.attr_float)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=MUTATION_SIGMA, indpb=MUTATION_PROB)
# toolbox.register("select", tools.selRoulette)
toolbox.register("select", tools.selTournament, tournsize=TOURNAMENT_SIZE)

# Callback untuk logging
class EpochLogger(tf.keras.callbacks.Callback):
    def __init__(self, fold):
        super().__init__()
        self.fold = fold

    def on_epoch_end(self, epoch, logs=None):
        train_loss = logs.get('loss')
        val_loss = logs.get('val_loss')
        print(f"Fold {self.fold} - GADAM - Epoch {epoch + 1}: Loss Latih = {train_loss:.6f}, Loss Validasi = {val_loss:.6f}")

# Buat direktori untuk menyimpan model jika belum ada
os.makedirs('models', exist_ok=True)

# Loop untuk setiap fold
for fold, (train_idx, test_idx) in enumerate(tscv.split(X), 1):
    print(f"\n=== Melatih GADAM Fold {fold} ===")
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    train_close = close_values[train_idx]
    test_close = close_values[test_idx]
    train_dates = dates[train_idx]
    test_dates = dates[test_idx]

    # Buat model untuk GA
    ga_model = build_ann_model(INPUT_DIM, HIDDEN_NEURONS, use_dropout=False, use_l2=False)

    # Register fungsi evaluasi
    toolbox.register("evaluate", evaluate_individual, model=ga_model, X=X_train, y=y_train)

    # Jalankan GA
    population = toolbox.population(n=POPULATION_SIZE)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("avg", np.mean)
    stats.register("max", np.max)
    hof = tools.HallOfFame(1)

    # List untuk menyimpan fitness per generasi
    fitness_avg_history = []
    fitness_max_history = []

    for gen in range(GENERATIONS):
        population = algorithms.varAnd(population, toolbox, cxpb=CROSSOVER_PROB, mutpb=MUTATION_PROB)
        invalid_ind = [ind for ind in population if not ind.fitness.valid]
        fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit
        hof.update(population)
        population = toolbox.select(population, len(population))
        record = stats.compile(population)
        fitness_avg_history.append(record['avg'])
        fitness_max_history.append(record['max'])
        print(f"Generasi {gen + 1}: Rata-rata Fitness (1/RMSE) = {record['avg']:.6f}, Maksimum Fitness (1/RMSE) = {record['max']:.6f}")

    # Visualisasi kurva fitness
    plt.figure(figsize=(10, 5))
    plt.plot(range(1, GENERATIONS + 1), fitness_avg_history, label='Rata-rata Fitness (1/RMSE)', color='blue')
    plt.plot(range(1, GENERATIONS + 1), fitness_max_history, label='Maksimum Fitness (1/RMSE)', color='red')
    plt.title(f'Kurva Fitness selama Generasi GA - GADAM (Fold {fold}, Glorot Init)')
    plt.xlabel('Generasi')
    plt.ylabel('Fitness (1/RMSE)')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f'ihsg_fitness_curve_gadam_fold_{fold}_glorot.png')
    plt.show()

    best_weights = hof[0]
    gadam_best_weights.append(best_weights)

    # Buat model GADAM dan set bobot awal
    gadam_model = build_ann_model(INPUT_DIM, HIDDEN_NEURONS, use_dropout=False, use_l2=False)
    set_model_weights(gadam_model, best_weights)

    # Latih dengan ADAM
    history = gadam_model.fit(X_train, y_train,
                              epochs=EPOCHS,
                              batch_size=BATCH_SIZE,
                              validation_data=(X_test, y_test),
                              verbose=0,
                              callbacks=[EpochLogger(fold),
                                         tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=EARLY_STOP_PATIENCE, verbose=1),
                                         LearningRateScheduler(lr_scheduler)])
    gadam_history.append(history.history)

    # Prediksi
    gadam_predictions = gadam_model.predict(np.concatenate([X_train, X_test]), verbose=0).flatten()
    gadam_predictions_denorm = denormalize(gadam_predictions, close_min, close_max)

    # Simpan model
    gadam_model.save(f'models/gadam_fold_{fold}.keras')

    # Simpan prediksi
    fold_pred_df = pd.DataFrame({
        'Fold': fold,
        'Date': np.concatenate([train_dates, test_dates]),
        'Actual_Close': np.concatenate([train_close, test_close]),
        'Predicted_GADAM': gadam_predictions_denorm,
        'Data': ['Latih'] * len(train_dates) + ['Uji'] * len(test_dates)
    })
    gadam_predictions_per_fold.append(fold_pred_df)

    # Bersihkan memori
    import gc
    gc.collect()
    tf.keras.backend.clear_session()
# Out:
# === Melatih GADAM Fold 1 ===
# Generasi 1: Rata-rata Fitness (1/RMSE) = 9.741687, Maksimum Fitness (1/RMSE) = 28.582966
# Generasi 2: Rata-rata Fitness (1/RMSE) = 14.350076, Maksimum Fitness (1/RMSE) = 28.582966
# Generasi 3: Rata-rata Fitness (1/RMSE) = 17.654761, Maksimum Fitness (1/RMSE) = 28.582966
# Generasi 4: Rata-rata Fitness (1/RMSE) = 19.133597, Maksimum Fitness (1/RMSE) = 27.365987
# Generasi 5: Rata-rata Fitness (1/RMSE) = 21.254044, Maksimum Fitness (1/RMSE) = 27.365987
# Generasi 6: Rata-rata Fitness (1/RMSE) = 20.825900, Maksimum Fitness (1/RMSE) = 26.505703
# Generasi 7: Rata-rata Fitness (1/RMSE) = 24.120153, Maksimum Fitness (1/RMSE) = 26.505703
# Generasi 8: Rata-rata Fitness (1/RMSE) = 25.252426, Maksimum Fitness (1/RMSE) = 26.505703
# Generasi 9: Rata-rata Fitness (1/RMSE) = 25.330336, Maksimum Fitness (1/RMSE) = 27.365987
# Generasi 10: Rata-rata Fitness (1/RMSE) = 26.207421, Maksimum Fitness (1/RMSE) = 27.365987
# Generasi
Rata-rata Fitness (1/RMSE) = 28.424502, Maksimum Fitness (1/RMSE) = 28.424502
# Generasi 99: Rata-rata Fitness (1/RMSE) = 28.424502, Maksimum Fitness (1/RMSE) = 28.424502
# Generasi 100: Rata-rata Fitness (1/RMSE) = 28.425097, Maksimum Fitness (1/RMSE) = 28.454259
# Fold 1 - GADAM - Epoch 1: Loss Latih = 0.001236, Loss Validasi = 0.000725
# Fold 1 - GADAM - Epoch 2: Loss Latih = 0.001211, Loss Validasi = 0.000755
# Fold 1 - GADAM - Epoch 3: Loss Latih = 0.001219, Loss Validasi = 0.000735
# Fold 1 - GADAM - Epoch 4: Loss Latih = 0.001211, Loss Validasi = 0.000722
# Fold 1 - GADAM - Epoch 5: Loss Latih = 0.001204, Loss Validasi = 0.000727
# Fold 1 - GADAM - Epoch 6: Loss Latih = 0.001201, Loss Validasi = 0.000734
# Fold 1 - GADAM - Epoch 7: Loss Latih = 0.001202, Loss Validasi = 0.000727
# Fold 1 - GADAM - Epoch 8: Loss Latih = 0.001199, Loss Validasi = 0.000721
# Fold 1 - GADAM - Epoch 9: Loss Latih = 0.001196, Loss Validasi = 0.000723
# Fold 1 - GADAM - Epoch 10: Loss Latih = 0.001194, Loss Validasi = 0.000726
# Fold 1 - GADAM - Epoch 11: Loss Latih = 0.001194, Loss Validasi = 0.000723
# Fold 1 - GADAM - Epoch 12: Loss Latih = 0.001193, Loss Validasi = 0.000721
# Fold 1 - GADAM - Epoch 13: Loss Latih = 0.001191, Loss Validasi = 0.000722
# Fold 1 - GADAM - Epoch 14: Loss Latih = 0.001191, Loss Validasi = 0.000722
# Fold 1 - GADAM - Epoch 15: Loss Latih = 0.001190, Loss Validasi = 0.000721
# Fold 1 - GADAM - Epoch 16: Loss Latih = 0.001190, Loss Validasi = 0.000721
# Fold 1 - GADAM - Epoch 17: Loss Latih = 0.001189, Loss Validasi = 0.000721
# Fold 1 - GADAM - Epoch 18: Loss Latih = 0.001189, Loss Validasi = 0.000721
# Fold 1 - GADAM - Epoch 19: Loss Latih = 0.001188, Loss Validasi = 0.000721
# Fold 1 - GADAM - Epoch 20: Loss Latih = 0.001188, Loss Validasi = 0.000721
# Fold 1 - GADAM - Epoch 21: Loss Latih = 0.001188, Loss Validasi = 0.000721
# Fold 1 - GADAM - Epoch 22: Loss Latih = 0.001187, Loss Validasi = 0.000721
# Fold 1 - GADAM - Epoch 23: Loss Latih = 0.001187, Loss Validasi = 0.000721
# Fold 1 - GADAM - Epoch 24: Loss Latih = 0.001187, Loss Validasi = 0.000720
# Fold 1 - GADAM - Epoch 25: Loss Latih = 0.001187, Loss Validasi = 0.000721
# Fold 1 - GADAM - Epoch 26: Loss Latih = 0.001187, Loss Validasi = 0.000721
# Fold 1 - GADAM - Epoch 27: Loss Latih = 0.001187, Loss Validasi = 0.000721
# Fold 1 - GADAM - Epoch 28: Loss Latih = 0.001186, Loss Validasi = 0.000721
# Fold 1 - GADAM - Epoch 29: Loss Latih = 0.001186, Loss Validasi = 0.000721
# Epoch 29: early stopping
#
# === Melatih GADAM Fold 2 ===
# Generasi 1: Rata-rata Fitness (1/RMSE) = 7.762549, Maksimum Fitness (1/RMSE) = 21.198994
# Generasi 2: Rata-rata Fitness (1/RMSE) = 12.678732, Maksimum Fitness (1/RMSE) = 21.198994
# Generasi 3: Rata-rata Fitness (1/RMSE) = 19.203801, Maksimum Fitness (1/RMSE) = 27.912705
# Generasi 4: Rata-rata Fitness (1/RMSE) = 20.591107, Maksimum Fitness (1/RMSE) = 26.725219
# Generasi 5: Rata-rata Fitness (1/RMSE) = 22.157624, Maksimum Fitness (1/RMSE) = 23.659599
# Generasi
Rata-rata Fitness (1/RMSE) = 31.722250, Maksimum Fitness (1/RMSE) = 31.722250
# Generasi 89: Rata-rata Fitness (1/RMSE) = 31.722250, Maksimum Fitness (1/RMSE) = 31.722250
# Generasi 90: Rata-rata Fitness (1/RMSE) = 31.722250, Maksimum Fitness (1/RMSE) = 31.722250
# Generasi 91: Rata-rata Fitness (1/RMSE) = 31.722250, Maksimum Fitness (1/RMSE) = 31.722250
# Generasi 92: Rata-rata Fitness (1/RMSE) = 31.722250, Maksimum Fitness (1/RMSE) = 31.722250
# Generasi 93: Rata-rata Fitness (1/RMSE) = 31.722250, Maksimum Fitness (1/RMSE) = 31.722250
# Generasi 94: Rata-rata Fitness (1/RMSE) = 31.722250, Maksimum Fitness (1/RMSE) = 31.722250
# Generasi 95: Rata-rata Fitness (1/RMSE) = 31.722250, Maksimum Fitness (1/RMSE) = 31.722250
# Generasi 96: Rata-rata Fitness (1/RMSE) = 31.722250, Maksimum Fitness (1/RMSE) = 31.722250
# Generasi 97: Rata-rata Fitness (1/RMSE) = 31.722250, Maksimum Fitness (1/RMSE) = 31.722250
# Generasi 98: Rata-rata Fitness (1/RMSE) = 31.722250, Maksimum Fitness (1/RMSE) = 31.722250
# Generasi 99: Rata-rata Fitness (1/RMSE) = 31.722250, Maksimum Fitness (1/RMSE) = 31.722250
# Generasi 100: Rata-rata Fitness (1/RMSE) = 31.722250, Maksimum Fitness (1/RMSE) = 31.722250
# Fold 3 - GADAM - Epoch 1: Loss Latih = 0.001000, Loss Validasi = 0.001407
# Fold 3 - GADAM - Epoch 2: Loss Latih = 0.000992, Loss Validasi = 0.001404
# Fold 3 - GADAM - Epoch 3: Loss Latih = 0.000983, Loss Validasi = 0.001407
# Fold 3 - GADAM - Epoch 4: Loss Latih = 0.000975, Loss Validasi = 0.001401
# Fold 3 - GADAM - Epoch 5: Loss Latih = 0.000972, Loss Validasi = 0.001401
# Fold 3 - GADAM - Epoch 6: Loss Latih = 0.000971, Loss Validasi = 0.001403
# Fold 3 - GADAM - Epoch 7: Loss Latih = 0.000969, Loss Validasi = 0.001405
# Fold 3 - GADAM - Epoch 8: Loss Latih = 0.000967, Loss Validasi = 0.001405
# Fold 3 - GADAM - Epoch 9: Loss Latih = 0.000965, Loss Validasi = 0.001406
# Fold 3 - GADAM - Epoch 10: Loss Latih = 0.000964, Loss Validasi = 0.001407
# Epoch 10: early stopping
#
# === Melatih GADAM Fold 4 ===
# Generasi 1: Rata-rata Fitness (1/RMSE) = 3.957624, Maksimum Fitness (1/RMSE) = 9.819307
# Generasi 2: Rata-rata Fitness (1/RMSE) = 6.017631, Maksimum Fitness (1/RMSE) = 9.794607
# Generasi 3: Rata-rata Fitness (1/RMSE) = 8.952966, Maksimum Fitness (1/RMSE) = 22.188002
# Generasi 4: Rata-rata Fitness (1/RMSE) = 16.349972, Maksimum Fitness (1/RMSE) = 33.214215
# Generasi 5: Rata-rata Fitness (1/RMSE) = 16.896187, Maksimum Fitness (1/RMSE) = 33.214215
# Generasi 6: Rata-rata Fitness (1/RMSE) = 21.934132, Maksimum Fitness (1/RMSE) = 33.214215
# Generasi 7: Rata-rata Fitness (1/RMSE) = 24.452051, Maksimum Fitness (1/RMSE) = 33.214215
# Generasi 8: Rata-rata Fitness (1/RMSE) = 31.029822, Maksimum Fitness (1/RMSE) = 33.278008
# Generasi 9: Rata-rata Fitness (1/RMSE) = 33.301324, Maksimum Fitness (1/RMSE) = 33.542041
# Generasi 10: Rata-rata Fitness (1/RMSE) = 33.432954, Maksimum Fitness (1/RMSE) = 33.542041
# Generasi 11: Rata-rata Fitness (1/RMSE) = 33.545716, Maksimum Fitness (1/RMSE) = 33.648132
# Generasi 12: Rata-rata Fitness (1/RMSE) = 33.604036, Maksimum Fitness (1/RMSE) = 33.648132
# Generasi 13: Rata-rata Fitness (1/RMSE) = 33.649665, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 14: Rata-rata Fitness (1/RMSE) = 33.714241, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 15: Rata-rata Fitness (1/RMSE) = 33.750495, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 16: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 17: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 18: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 19: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 20: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 21: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 22: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 23: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 24: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 25: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 26: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 27: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 28: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 29: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 30: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 31: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 32: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 33: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 34: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 35: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 36: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 37: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 38: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 39: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 40: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 41: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 42: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 43: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 44: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 45: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 46: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 47: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 48: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 49: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 50: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 51: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 52: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 53: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 54: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 55: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 56: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 57: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 58: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 59: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 60: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 61: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 62: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 63: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 64: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 65: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 66: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 67: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 68: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 69: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 70: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 71: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 72: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 73: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 74: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 75: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 76: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 77: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 78: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 79: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 80: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 81: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 82: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 83: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 84: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 85: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 86: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 87: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 88: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 89: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 90: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 91: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 92: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 93: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 94: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 95: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 96: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 97: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 98: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 99: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Generasi 100: Rata-rata Fitness (1/RMSE) = 33.754760, Maksimum Fitness (1/RMSE) = 33.754760
# Fold 4 - GADAM - Epoch 1: Loss Latih = 0.000902, Loss Validasi = 0.002141
# Fold 4 - GADAM - Epoch 2: Loss Latih = 0.000888, Loss Validasi = 0.002150
# Fold 4 - GADAM - Epoch 3: Loss Latih = 0.000882, Loss Validasi = 0.002154
# Fold 4 - GADAM - Epoch 4: Loss Latih = 0.000881, Loss Validasi = 0.002158
# Fold 4 - GADAM - Epoch 5: Loss Latih = 0.000880, Loss Validasi = 0.002166
# Fold 4 - GADAM - Epoch 6: Loss Latih = 0.000881, Loss Validasi = 0.002165
# Epoch 6: early stopping

# %% [markdown]
# ## 8. Validasi GADAM per Fold
# Mengevaluasi performa GADAM pada setiap fold dan membuat visualisasi.

# %%
for fold, (train_idx, test_idx) in enumerate(tscv.split(X), 1):
    print(f"\n=== Validasi GADAM Fold {fold} ===")
    train_close = close_values[train_idx]
    test_close = close_values[test_idx]
    train_dates = dates[train_idx]
    test_dates = dates[test_idx]

    # Ambil prediksi
    fold_pred_df = gadam_predictions_per_fold[fold-1]
    gadam_pred = fold_pred_df['Predicted_GADAM'].values
    train_pred = gadam_pred[:len(train_close)]
    test_pred = gadam_pred[len(train_close):]

    # Hitung metrik
    rmse_train, mae_train, mape_train = calculate_metrics(train_close, train_pred)
    rmse_test, mae_test, mape_test = calculate_metrics(test_close, test_pred)
    gadam_metrics.append({'Fold': fold, 'Data': 'Latih', 'RMSE': rmse_train, 'MAE': mae_train, 'MAPE': mape_train})
    gadam_metrics.append({'Fold': fold, 'Data': 'Uji', 'RMSE': rmse_test, 'MAE': mae_test, 'MAPE': mape_test})

    # Visualisasi prediksi vs aktual
    plt.figure(figsize=(14, 6))
    plt.plot(train_dates, train_close, label='Aktual (Latih)', color='blue', alpha=0.5)
    plt.plot(train_dates, train_pred, label='GADAM (Latih)', color='purple')
    plt.plot(test_dates, test_close, label='Aktual (Uji)', color='green', alpha=0.5)
    plt.plot(test_dates, test_pred, label='GADAM (Uji)', color='pink')
    plt.title(f'Prediksi Harga IHSG dengan GADAM - Fold {fold}')
    plt.xlabel('Tanggal')
    plt.ylabel('Harga Penutupan')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(f'ihsg_prediction_gadam_fold_{fold}_glorot.png')
    plt.show()

    # Visualisasi kurva loss
    history = gadam_history[fold-1]
    plt.figure(figsize=(10, 5))
    plt.plot(history['loss'], label='Loss Latih (GADAM)', color='blue')
    plt.plot(history['val_loss'], label='Loss Uji (GADAM)', color='orange')
    plt.title(f'Kurva Loss Pelatihan - GADAM (Fold {fold}, Glorot Init)')
    plt.xlabel('Epoch')
    plt.ylabel('Mean Squared Error')
    plt.legend()
    plt.grid(True)
    plt.savefig(f'ihsg_loss_curve_gadam_fold_{fold}_glorot.png')
    plt.show()
# Out:
# === Validasi GADAM Fold 1 ===
# === Validasi GADAM Fold 2 ===
# === Validasi GADAM Fold 3 ===
# === Validasi GADAM Fold 4 ===

# %% [markdown]
# ## 9. Pelatihan ADAM per Fold
# Melatih model ANN langsung dengan ADAM tanpa optimasi GA.

# %%
# Inisialisasi untuk menyimpan hasil
adam_metrics = []
adam_predictions_per_fold = []
adam_history = []

# Callback untuk logging
class EpochLogger(tf.keras.callbacks.Callback):
    def __init__(self, fold):
        super().__init__()
        self.fold = fold

    def on_epoch_end(self, epoch, logs=None):
        train_loss = logs.get('loss')
        val_loss = logs.get('val_loss')
        print(f"Fold {self.fold} - ADAM - Epoch {epoch + 1}: Loss Latih = {train_loss:.6f}, Loss Validasi = {val_loss:.6f}")

# Loop untuk setiap fold
for fold, (train_idx, test_idx) in enumerate(tscv.split(X), 1):
    print(f"\n=== Melatih ADAM Fold {fold} ===")
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    train_close = close_values[train_idx]
    test_close = close_values[test_idx]
    train_dates = dates[train_idx]
    test_dates = dates[test_idx]

    # Buat model ADAM
    adam_model = build_ann_model(INPUT_DIM, HIDDEN_NEURONS, use_dropout=True, use_l2=True)

    # Latih dengan ADAM
    history = adam_model.fit(X_train, y_train,
                             epochs=EPOCHS,
                             batch_size=BATCH_SIZE,
                             validation_data=(X_test, y_test),
                             verbose=0,
                             callbacks=[EpochLogger(fold),
                                        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=EARLY_STOP_PATIENCE, verbose=1),
                                        LearningRateScheduler(lr_scheduler)])
    adam_history.append(history.history)

    # Prediksi
    adam_predictions = adam_model.predict(np.concatenate([X_train, X_test]), verbose=0).flatten()
    adam_predictions_denorm = denormalize(adam_predictions, close_min, close_max)

    # Simpan model
    adam_model.save(f'models/adam_fold_{fold}.keras')

    # Simpan prediksi
    fold_pred_df = pd.DataFrame({
        'Fold': fold,
        'Date': np.concatenate([train_dates, test_dates]),
        'Actual_Close': np.concatenate([train_close, test_close]),
        'Predicted_ADAM': adam_predictions_denorm,
        'Data': ['Latih'] * len(train_dates) + ['Uji'] * len(test_dates)
    })
    adam_predictions_per_fold.append(fold_pred_df)

    # Bersihkan memori
    import gc
    gc.collect()
    tf.keras.backend.clear_session()
# Out:
# === Melatih ADAM Fold 1 ===
# Fold 1 - ADAM - Epoch 1: Loss Latih = 0.109815, Loss Validasi = 0.030434
# Fold 1 - ADAM - Epoch 2: Loss Latih = 0.090231, Loss Validasi = 0.029993
# Fold 1 - ADAM - Epoch 3: Loss Latih = 0.087135, Loss Validasi = 0.029957
# Fold 1 - ADAM - Epoch 4: Loss Latih = 0.087959, Loss Validasi = 0.030013
# Fold 1 - ADAM - Epoch 5: Loss Latih = 0.092266, Loss Validasi = 0.030207
# Fold 1 - ADAM - Epoch 6: Loss Latih = 0.083243, Loss Validasi = 0.030293
# Fold 1 - ADAM - Epoch 7: Loss Latih = 0.090692, Loss Validasi = 0.030085
# Fold 1 - ADAM - Epoch 8: Loss Latih = 0.080867, Loss Validasi = 0.029586
# Fold 1 - ADAM - Epoch 9: Loss Latih = 0.066863, Loss Validasi = 0.029241
# Fold 1 - ADAM - Epoch 10: Loss Latih = 0.078416, Loss Validasi = 0.029330
# Fold 1 - ADAM - Epoch 11: Loss Latih = 0.075803, Loss Validasi = 0.029254
# Fold 1 - ADAM - Epoch 12: Loss Latih = 0.079865, Loss Validasi = 0.028792
# Fold 1 - ADAM - Epoch 13: Loss Latih = 0.063291, Loss Validasi = 0.028080
# Fold 1 - ADAM - Epoch 14: Loss Latih = 0.062429, Loss Validasi = 0.027789
# Fold 1 - ADAM - Epoch 15: Loss Latih = 0.060761, Loss Validasi = 0.027486
# Fold 1 - ADAM - Epoch 16: Loss Latih = 0.053702, Loss Validasi = 0.027126
# Fold 1 - ADAM - Epoch 17: Loss Latih = 0.056604, Loss Validasi = 0.026726
# Fold 1 - ADAM - Epoch 18: Loss Latih = 0.054063, Loss Validasi = 0.026369
# Fold 1 - ADAM - Epoch 19: Loss Latih = 0.056209, Loss Validasi = 0.026127
# Fold 1 - ADAM - Epoch 20: Loss Latih = 0.048648, Loss Validasi = 0.026071
# Fold 1 - ADAM - Epoch 21: Loss Latih = 0.053720, Loss Validasi = 0.026011
# Fold 1 - ADAM - Epoch 22: Loss Latih = 0.047472, Loss Validasi = 0.025854
# Fold 1 - ADAM - Epoch 23: Loss Latih = 0.047668, Loss Validasi = 0.025628
# Fold 1 - ADAM - Epoch 24: Loss Latih = 0.050209, Loss Validasi = 0.025318
# Fold 1 - ADAM - Epoch 25: Loss Latih = 0.052684, Loss Validasi = 0.024839
# Fold 1 - ADAM - Epoch 26: Loss Latih = 0.046343, Loss Validasi = 0.024385
# Fold 1 - ADAM - Epoch 27: Loss Latih = 0.041242, Loss Validasi = 0.024156
# Fold 1 - ADAM - Epoch 28: Loss Latih = 0.045612, Loss Validasi = 0.024078
# Fold 1 - ADAM - Epoch 29: Loss Latih = 0.047614, Loss Validasi = 0.023981
# Fold 1 - ADAM - Epoch 30: Loss Latih = 0.039831, Loss Validasi = 0.023961
# Fold 1 - ADAM - Epoch 31: Loss Latih = 0.041706, Loss Validasi = 0.023916
# Fold 1 - ADAM - Epoch 32: Loss Latih = 0.044443, Loss Validasi = 0.023663
# Fold 1 - ADAM - Epoch 33: Loss Latih = 0.043258, Loss Validasi = 0.023315
# Fold 1 - ADAM - Epoch 34: Loss Latih = 0.039195, Loss Validasi = 0.022910
# Fold 1 - ADAM - Epoch 35: Loss Latih = 0.042521, Loss Validasi = 0.022585
# Fold 1 - ADAM - Epoch 36: Loss Latih = 0.040229, Loss Validasi = 0.022349
# Fold 1 - ADAM - Epoch 37: Loss Latih = 0.034171, Loss Validasi = 0.022189
# Fold 1 - ADAM - Epoch 38: Loss Latih = 0.037661, Loss Validasi = 0.022017
# Fold 1 - ADAM - Epoch 39: Loss Latih = 0.037159, Loss Validasi = 0.021937
# Fold 1 - ADAM - Epoch 40: Loss Latih = 0.037871, Loss Validasi = 0.021762
# Fold 1 - ADAM - Epoch 41: Loss Latih = 0.035351, Loss Validasi = 0.021530
# Fold 1 - ADAM - Epoch 42: Loss Latih = 0.035357, Loss Validasi = 0.021344
# Fold 1 - ADAM - Epoch 43: Loss Latih = 0.035882, Loss Validasi = 0.021048
# Fold 1 - ADAM - Epoch 44: Loss Latih = 0.039433, Loss Validasi = 0.020727
# Fold 1 - ADAM - Epoch 45: Loss Latih = 0.033692, Loss Validasi = 0.020645
# Fold 1 - ADAM - Epoch 46: Loss Latih = 0.031814, Loss Validasi = 0.020628
# Fold 1 - ADAM - Epoch 47: Loss Latih = 0.035846, Loss Validasi = 0.020630
# Fold 1 - ADAM - Epoch 48: Loss Latih = 0.032425, Loss Validasi = 0.020589
# Fold 1 - ADAM - Epoch 49: Loss Latih = 0.036380, Loss Validasi = 0.020511
# Fold 1 - ADAM - Epoch 50: Loss Latih = 0.031333, Loss Validasi = 0.020307
# Fold 1 - ADAM - Epoch 51: Loss Latih = 0.029411, Loss Validasi = 0.020125
# Fold 1 - ADAM - Epoch 52: Loss Latih = 0.030241, Loss Validasi = 0.019951
# Fold 1 - ADAM - Epoch 53: Loss Latih = 0.029922, Loss Validasi = 0.019757
# Fold 1 - ADAM - Epoch 54: Loss Latih = 0.030809, Loss Validasi = 0.019564
# Fold 1 - ADAM - Epoch 55: Loss Latih = 0.031419, Loss Validasi = 0.019333
# Fold 1 - ADAM - Epoch 56: Loss Latih = 0.030129, Loss Validasi = 0.019133
# Fold 1 - ADAM - Epoch 57: Loss Latih = 0.029619, Loss Validasi = 0.018889
# Fold 1 - ADAM - Epoch 58: Loss Latih = 0.028890, Loss Validasi = 0.018730
# Fold 1 - ADAM - Epoch 59: Loss Latih = 0.030530, Loss Validasi = 0.018625
# Fold 1 - ADAM - Epoch 60: Loss Latih = 0.028954, Loss Validasi = 0.018472
# Fold 1 - ADAM - Epoch 61: Loss Latih = 0.027389, Loss Validasi = 0.018343
# Fold 1 - ADAM - Epoch 62: Loss Latih = 0.028560, Loss Validasi = 0.018180
# Fold 1 - ADAM - Epoch 63: Loss Latih = 0.026328, Loss Validasi = 0.018049
# Fold 1 - ADAM - Epoch 64: Loss Latih = 0.024720, Loss Validasi = 0.017983
# Fold 1 - ADAM - Epoch 65: Loss Latih = 0.026856, Loss Validasi = 0.017926
# Fold 1 - ADAM - Epoch 66: Loss Latih = 0.025276, Loss Validasi = 0.017800
# Fold 1 - ADAM - Epoch 67: Loss Latih = 0.029004, Loss Validasi = 0.017615
# Fold 1 - ADAM - Epoch 68: Loss Latih = 0.025460, Loss Validasi = 0.017471
# Fold 1 - ADAM - Epoch 69: Loss Latih = 0.025246, Loss Validasi = 0.017349
# Fold 1 - ADAM - Epoch 70: Loss Latih = 0.025644, Loss Validasi = 0.017242
# Fold 1 - ADAM - Epoch 71: Loss Latih = 0.023671, Loss Validasi = 0.017130
# Fold 1 - ADAM - Epoch 72: Loss Latih = 0.024398, Loss Validasi = 0.017038
# Fold 1 - ADAM - Epoch 73: Loss Latih = 0.024493, Loss Validasi = 0.016962
# Fold 1 - ADAM - Epoch 74: Loss Latih = 0.023699, Loss Validasi = 0.016917
# Fold 1 - ADAM - Epoch 75: Loss Latih = 0.024044, Loss Validasi = 0.016843
# Fold 1 - ADAM - Epoch 76: Loss Latih = 0.023412, Loss Validasi = 0.016828
# Fold 1 - ADAM - Epoch 77: Loss Latih = 0.025381, Loss Validasi = 0.016767
# Fold 1 - ADAM - Epoch 78: Loss Latih = 0.022496, Loss Validasi = 0.016685
# Fold 1 - ADAM - Epoch 79: Loss Latih = 0.022811, Loss Validasi = 0.016584
# Fold 1 - ADAM - Epoch 80: Loss Latih = 0.021077, Loss Validasi = 0.016490
# Fold 1 - ADAM - Epoch 81: Loss Latih = 0.022377, Loss Validasi = 0.016405
# Fold 1 - ADAM - Epoch 82: Loss Latih = 0.021633, Loss Validasi = 0.016358
# Fold 1 - ADAM - Epoch 83: Loss Latih = 0.026776, Loss Validasi = 0.016286
# Fold 1 - ADAM - Epoch 84: Loss Latih = 0.021249, Loss Validasi = 0.016213
# Fold 1 - ADAM - Epoch 85: Loss Latih = 0.022347, Loss Validasi = 0.016142
# Fold 1 - ADAM - Epoch 86: Loss Latih = 0.022462, Loss Validasi = 0.016078
# Fold 1 - ADAM - Epoch 87: Loss Latih = 0.022648, Loss Validasi = 0.016032
# Fold 1 - ADAM - Epoch 88: Loss Latih = 0.023362, Loss Validasi = 0.016006
# Fold 1 - ADAM - Epoch 89: Loss Latih = 0.023155, Loss Validasi = 0.015985
# Fold 1 - ADAM - Epoch 90: Loss Latih = 0.022483, Loss Validasi = 0.015962
# Fold 1 - ADAM - Epoch 91: Loss Latih = 0.021518, Loss Validasi = 0.015928
# Fold 1 - ADAM - Epoch 92: Loss Latih = 0.020919, Loss Validasi = 0.015908
# Fold 1 - ADAM - Epoch 93: Loss Latih = 0.022384, Loss Validasi = 0.015884
# Fold 1 - ADAM - Epoch 94: Loss Latih = 0.022834, Loss Validasi = 0.015860
# Fold 1 - ADAM - Epoch 95: Loss Latih = 0.022114, Loss Validasi = 0.015842
# Fold 1 - ADAM - Epoch 96: Loss Latih = 0.022551, Loss Validasi = 0.015822
# Fold 1 - ADAM - Epoch 97: Loss Latih = 0.021801, Loss Validasi = 0.015803
# Fold 1 - ADAM - Epoch 98: Loss Latih = 0.021260, Loss Validasi = 0.015784
# Fold 1 - ADAM - Epoch 99: Loss Latih = 0.022151, Loss Validasi = 0.015769
# Fold 1 - ADAM - Epoch 100: Loss Latih = 0.021478, Loss Validasi = 0.015755
#
# === Melatih ADAM Fold 2 ===
# Fold 2 - ADAM - Epoch 1: Loss Latih = 0.507377, Loss Validasi = 0.362395
# Fold 2 - ADAM - Epoch 2: Loss Latih = 0.433646, Loss Validasi = 0.314388
# Fold 2 - ADAM - Epoch 3: Loss Latih = 0.380673, Loss Validasi = 0.270448
# Fold 2 - ADAM - Epoch 4: Loss Latih = 0.320738, Loss Validasi = 0.230567
# Fold 2 - ADAM - Epoch 5: Loss Latih = 0.273946, Loss Validasi = 0.194586
# Fold 2 - ADAM - Epoch 6: Loss Latih = 0.244454, Loss Validasi = 0.162495
# Fold 2 - ADAM - Epoch 7: Loss Latih = 0.202227, Loss Validasi = 0.134295
# Fold 2 - ADAM - Epoch 8: Loss Latih = 0.166473, Loss Validasi = 0.109947
# Fold 2 - ADAM - Epoch 9: Loss Latih = 0.135707, Loss Validasi = 0.086765
# Fold 2 - ADAM - Epoch 10: Loss Latih = 0.116218, Loss Validasi = 0.066243
# Fold 2 - ADAM - Epoch 11: Loss Latih = 0.090593, Loss Validasi = 0.050604
# Fold 2 - ADAM - Epoch 12: Loss Latih = 0.071813, Loss Validasi = 0.040083
# Fold 2 - ADAM - Epoch 13: Loss Latih = 0.057925, Loss Validasi = 0.033502
# Fold 2 - ADAM - Epoch 14: Loss Latih = 0.053669, Loss Validasi = 0.029668
# Fold 2 - ADAM - Epoch 15: Loss Latih = 0.052671, Loss Validasi = 0.027704
# Fold 2 - ADAM - Epoch 16: Loss Latih = 0.044396, Loss Validasi = 0.026772
# Fold 2 - ADAM - Epoch 17: Loss Latih = 0.046777, Loss Validasi = 0.026262
# Fold 2 - ADAM - Epoch 18: Loss Latih = 0.046140, Loss Validasi = 0.025935
# Fold 2 - ADAM - Epoch 19: Loss Latih = 0.044821, Loss Validasi = 0.025650
# Fold 2 - ADAM - Epoch 20: Loss Latih = 0.046492, Loss Validasi = 0.025371
# Fold 2 - ADAM - Epoch 21: Loss Latih = 0.044620, Loss Validasi = 0.025088
# Fold 2 - ADAM - Epoch 22: Loss Latih = 0.040648, Loss Validasi = 0.024819
# Fold 2 - ADAM - Epoch 23: Loss Latih = 0.045451, Loss Validasi = 0.024546
# Fold 2 - ADAM - Epoch 24: Loss Latih = 0.043865, Loss Validasi = 0.024281
# Fold 2 - ADAM - Epoch 25: Loss Latih = 0.041751, Loss Validasi = 0.024035
# Fold 2 - ADAM - Epoch 26: Loss Latih = 0.044110, Loss Validasi = 0.023793
# Fold 2 - ADAM - Epoch 27: Loss Latih = 0.045398, Loss Validasi = 0.023550
# Fold 2 - ADAM - Epoch 28: Loss Latih = 0.036673, Loss Validasi = 0.023314
# Fold 2 - ADAM - Epoch 29: Loss Latih = 0.038861, Loss Validasi = 0.023088
# Fold 2 - ADAM - Epoch 30: Loss Latih = 0.038942, Loss Validasi = 0.022869
# Fold 2 - ADAM - Epoch 31: Loss Latih = 0.038724, Loss Validasi = 0.022653
# Fold 2 - ADAM - Epoch 32: Loss Latih = 0.039589, Loss Validasi = 0.022448
# Fold 2 - ADAM - Epoch 33: Loss Latih = 0.037335, Loss Validasi = 0.022248
# Fold 2 - ADAM - Epoch 34: Loss Latih = 0.037374, Loss Validasi = 0.022054
# Fold 2 - ADAM - Epoch 35: Loss Latih = 0.036553, Loss Validasi = 0.021843
# Fold 2 - ADAM - Epoch 36: Loss Latih = 0.038436, Loss Validasi = 0.021641
# Fold 2 - ADAM - Epoch 37: Loss Latih = 0.038693, Loss Validasi = 0.021442
# Fold 2 - ADAM - Epoch 38: Loss Latih = 0.034795, Loss Validasi = 0.021232
# Fold 2 - ADAM - Epoch 39: Loss Latih = 0.035100, Loss Validasi = 0.021031
# Fold 2 - ADAM - Epoch 40: Loss Latih = 0.037473, Loss Validasi = 0.020840
# Fold 2 - ADAM - Epoch 41: Loss Latih = 0.036010, Loss Validasi = 0.020653
# Fold 2 - ADAM - Epoch 42: Loss Latih = 0.033679, Loss Validasi = 0.020472
# Fold 2 - ADAM - Epoch 43: Loss Latih = 0.035017, Loss Validasi = 0.020285
# Fold 2 - ADAM - Epoch 44: Loss Latih = 0.034756, Loss Validasi = 0.020112
# Fold 2 - ADAM - Epoch 45: Loss Latih = 0.033331, Loss Validasi = 0.019934
# Fold 2 - ADAM - Epoch 46: Loss Latih = 0.033130, Loss Validasi = 0.019752
# Fold 2 - ADAM - Epoch 47: Loss Latih = 0.032801, Loss Validasi = 0.019575
# Fold 2 - ADAM - Epoch 48: Loss Latih = 0.034292, Loss Validasi = 0.019406
# Fold 2 - ADAM - Epoch 49: Loss Latih = 0.032388, Loss Validasi = 0.019238
# Fold 2 - ADAM - Epoch 50: Loss Latih = 0.032187, Loss Validasi = 0.019066
# Fold 2 - ADAM - Epoch 51: Loss Latih = 0.031349, Loss Validasi = 0.018884
# Fold 2 - ADAM - Epoch 52: Loss Latih = 0.031039, Loss Validasi = 0.018701
# Fold 2 - ADAM - Epoch 53: Loss Latih = 0.028969, Loss Validasi = 0.018521
# Fold 2 - ADAM - Epoch 54: Loss Latih = 0.029290, Loss Validasi = 0.018349
# Fold 2 - ADAM - Epoch 55: Loss Latih = 0.030125, Loss Validasi = 0.018166
# Fold 2 - ADAM - Epoch 56: Loss Latih = 0.030939, Loss Validasi = 0.018004
# Fold 2 - ADAM - Epoch 57: Loss Latih = 0.030462, Loss Validasi = 0.017843
# Fold 2 - ADAM - Epoch 58: Loss Latih = 0.031137, Loss Validasi = 0.017666
# Fold 2 - ADAM - Epoch 59: Loss Latih = 0.028049, Loss Validasi = 0.017479
# Fold 2 - ADAM - Epoch 60: Loss Latih = 0.028223, Loss Validasi = 0.017283
# Fold 2 - ADAM - Epoch 61: Loss Latih = 0.027950, Loss Validasi = 0.017089
# Fold 2 - ADAM - Epoch 62: Loss Latih = 0.026202, Loss Validasi = 0.016905
# Fold 2 - ADAM - Epoch 63: Loss Latih = 0.031070, Loss Validasi = 0.016738
# Fold 2 - ADAM - Epoch 64: Loss Latih = 0.028714, Loss Validasi = 0.016580
# Fold 2 - ADAM - Epoch 65: Loss Latih = 0.027957, Loss Validasi = 0.016418
# Fold 2 - ADAM - Epoch 66: Loss Latih = 0.030449, Loss Validasi = 0.016253
# Fold 2 - ADAM - Epoch 67: Loss Latih = 0.024832, Loss Validasi = 0.016073
# Fold 2 - ADAM - Epoch 68: Loss Latih = 0.026313, Loss Validasi = 0.015897
# Fold 2 - ADAM - Epoch 69: Loss Latih = 0.026120, Loss Validasi = 0.015743
# Fold 2 - ADAM - Epoch 70: Loss Latih = 0.024404, Loss Validasi = 0.015633
# Fold 2 - ADAM - Epoch 71: Loss Latih = 0.024751, Loss Validasi = 0.015517
# Fold 2 - ADAM - Epoch 72: Loss Latih = 0.025796, Loss Validasi = 0.015382
# Fold 2 - ADAM - Epoch 73: Loss Latih = 0.025893, Loss Validasi = 0.015244
# Fold 2 - ADAM - Epoch 74: Loss Latih = 0.024892, Loss Validasi = 0.015104
# Fold 2 - ADAM - Epoch 75: Loss Latih = 0.024972, Loss Validasi = 0.014991
# Fold 2 - ADAM - Epoch 76: Loss Latih = 0.024758, Loss Validasi = 0.014890
# Fold 2 - ADAM - Epoch 77: Loss Latih = 0.024267, Loss Validasi = 0.014790
# Fold 2 - ADAM - Epoch 78: Loss Latih = 0.026125, Loss Validasi = 0.014704
# Fold 2 - ADAM - Epoch 79: Loss Latih = 0.024345, Loss Validasi = 0.014626
# Fold 2 - ADAM - Epoch 80: Loss Latih = 0.025005, Loss Validasi = 0.014562
# Fold 2 - ADAM - Epoch 81: Loss Latih = 0.024897, Loss Validasi = 0.014504
# Fold 2 - ADAM - Epoch 82: Loss Latih = 0.021841, Loss Validasi = 0.014438
# Fold 2 - ADAM - Epoch 83: Loss Latih = 0.023204, Loss Validasi = 0.014382
# Fold 2 - ADAM - Epoch 84: Loss Latih = 0.023052, Loss Validasi = 0.014327
# Fold 2 - ADAM - Epoch 85: Loss Latih = 0.022120, Loss Validasi = 0.014272
# Fold 2 - ADAM - Epoch 86: Loss Latih = 0.024352, Loss Validasi = 0.014221
# Fold 2 - ADAM - Epoch 87: Loss Latih = 0.022992, Loss Validasi = 0.014167
# Fold 2 - ADAM - Epoch 88: Loss Latih = 0.021999, Loss Validasi = 0.014124
# Fold 2 - ADAM - Epoch 89: Loss Latih = 0.022771, Loss Validasi = 0.014086
# Fold 2 - ADAM - Epoch 90: Loss Latih = 0.023651, Loss Validasi = 0.014053
# Fold 2 - ADAM - Epoch 91: Loss Latih = 0.022833, Loss Validasi = 0.014015
# Fold 2 - ADAM - Epoch 92: Loss Latih = 0.023297, Loss Validasi = 0.013980
# Fold 2 - ADAM - Epoch 93: Loss Latih = 0.023367, Loss Validasi = 0.013948
# Fold 2 - ADAM - Epoch 94: Loss Latih = 0.023263, Loss Validasi = 0.013925
# Fold 2 - ADAM - Epoch 95: Loss Latih = 0.022696, Loss Validasi = 0.013903
# Fold 2 - ADAM - Epoch 96: Loss Latih = 0.025210, Loss Validasi = 0.013883
# Fold 2 - ADAM - Epoch 97: Loss Latih = 0.023056, Loss Validasi = 0.013866
# Fold 2 - ADAM - Epoch 98: Loss Latih = 0.023669, Loss Validasi = 0.013846
# Fold 2 - ADAM - Epoch 99: Loss Latih = 0.022636, Loss Validasi = 0.013830
# Fold 2 - ADAM - Epoch 100: Loss Latih = 0.023984, Loss Validasi = 0.013820
#
# === Melatih ADAM Fold 3 ===
# Fold 3 - ADAM - Epoch 1: Loss Latih = 0.570278, Loss Validasi = 0.667748
# Fold 3 - ADAM - Epoch 2: Loss Latih = 0.455470, Loss Validasi = 0.484463
# Fold 3 - ADAM - Epoch 3: Loss Latih = 0.382124, Loss Validasi = 0.347514
# Fold 3 - ADAM - Epoch 4: Loss Latih = 0.293371, Loss Validasi = 0.252613
# Fold 3 - ADAM - Epoch 5: Loss Latih = 0.242581, Loss Validasi = 0.184372
# Fold 3 - ADAM - Epoch 6: Loss Latih = 0.214906, Loss Validasi = 0.139142
# Fold 3 - ADAM - Epoch 7: Loss Latih = 0.208955, Loss Validasi = 0.108739
# Fold 3 - ADAM - Epoch 8: Loss Latih = 0.189765, Loss Validasi = 0.090476
# Fold 3 - ADAM - Epoch 9: Loss Latih = 0.195726, Loss Validasi = 0.077533
# Fold 3 - ADAM - Epoch 10: Loss Latih = 0.171451, Loss Validasi = 0.072493
# Fold 3 - ADAM - Epoch 11: Loss Latih = 0.148696, Loss Validasi = 0.070079
# Fold 3 - ADAM - Epoch 12: Loss Latih = 0.154644, Loss Validasi = 0.064766
# Fold 3 - ADAM - Epoch 13: Loss Latih = 0.138973, Loss Validasi = 0.060782
# Fold 3 - ADAM - Epoch 14: Loss Latih = 0.120822, Loss Validasi = 0.059984
# Fold 3 - ADAM - Epoch 15: Loss Latih = 0.121758, Loss Validasi = 0.058943
# Fold 3 - ADAM - Epoch 16: Loss Latih = 0.116566, Loss Validasi = 0.056192
# Fold 3 - ADAM - Epoch 17: Loss Latih = 0.111619, Loss Validasi = 0.052776
# Fold 3 - ADAM - Epoch 18: Loss Latih = 0.113599, Loss Validasi = 0.050519
# Fold 3 - ADAM - Epoch 19: Loss Latih = 0.094146, Loss Validasi = 0.051754
# Fold 3 - ADAM - Epoch 20: Loss Latih = 0.099258, Loss Validasi = 0.052836
# Fold 3 - ADAM - Epoch 21: Loss Latih = 0.090913, Loss Validasi = 0.050773
# Fold 3 - ADAM - Epoch 22: Loss Latih = 0.080974, Loss Validasi = 0.051959
# Fold 3 - ADAM - Epoch 23: Loss Latih = 0.080471, Loss Validasi = 0.052104
# Epoch 23: early stopping
#
# === Melatih ADAM Fold 4 ===
# Fold 4 - ADAM - Epoch 1: Loss Latih = 0.537835, Loss Validasi = 0.390035
# Fold 4 - ADAM - Epoch 2: Loss Latih = 0.362753, Loss Validasi = 0.185411
# Fold 4 - ADAM - Epoch 3: Loss Latih = 0.262505, Loss Validasi = 0.100269
# Fold 4 - ADAM - Epoch 4: Loss Latih = 0.245887, Loss Validasi = 0.078292
# Fold 4 - ADAM - Epoch 5: Loss Latih = 0.213470, Loss Validasi = 0.071358
# Fold 4 - ADAM - Epoch 6: Loss Latih = 0.212219, Loss Validasi = 0.065350
# Fold 4 - ADAM - Epoch 7: Loss Latih = 0.186152, Loss Validasi = 0.061496
# Fold 4 - ADAM - Epoch 8: Loss Latih = 0.166923, Loss Validasi = 0.065188
# Fold 4 - ADAM - Epoch 9: Loss Latih = 0.159315, Loss Validasi = 0.063425
# Fold 4 - ADAM - Epoch 10: Loss Latih = 0.143779, Loss Validasi = 0.058146
# Fold 4 - ADAM - Epoch 11: Loss Latih = 0.134199, Loss Validasi = 0.056081
# Fold 4 - ADAM - Epoch 12: Loss Latih = 0.122089, Loss Validasi = 0.050627
# Fold 4 - ADAM - Epoch 13: Loss Latih = 0.101451, Loss Validasi = 0.052974
# Fold 4 - ADAM - Epoch 14: Loss Latih = 0.098601, Loss Validasi = 0.059494
# Fold 4 - ADAM - Epoch 15: Loss Latih = 0.092244, Loss Validasi = 0.058559
# Fold 4 - ADAM - Epoch 16: Loss Latih = 0.089368, Loss Validasi = 0.052237
# Fold 4 - ADAM - Epoch 17: Loss Latih = 0.079756, Loss Validasi = 0.053621
# Epoch 17: early stopping

# %% [markdown]
# ## 10. Validasi ADAM per Fold
# Mengevaluasi performa ADAM pada setiap fold dan membuat visualisasi.

# %%
for fold, (train_idx, test_idx) in enumerate(tscv.split(X), 1):
    print(f"\n=== Validasi ADAM Fold {fold} ===")
    train_close = close_values[train_idx]
    test_close = close_values[test_idx]
    train_dates = dates[train_idx]
    test_dates = dates[test_idx]

    # Ambil prediksi
    fold_pred_df = adam_predictions_per_fold[fold-1]
    adam_pred = fold_pred_df['Predicted_ADAM'].values
    train_pred = adam_pred[:len(train_close)]
    test_pred = adam_pred[len(train_close):]

    # Hitung metrik
    rmse_train, mae_train, mape_train = calculate_metrics(train_close, train_pred)
    rmse_test, mae_test, mape_test = calculate_metrics(test_close, test_pred)
    adam_metrics.append({'Fold': fold, 'Data': 'Latih', 'RMSE': rmse_train, 'MAE': mae_train, 'MAPE': mape_train})
    adam_metrics.append({'Fold': fold, 'Data': 'Uji', 'RMSE': rmse_test, 'MAE': mae_test, 'MAPE': mape_test})

    # Visualisasi prediksi vs aktual
    plt.figure(figsize=(14, 6))
    plt.plot(train_dates, train_close, label='Aktual (Latih)', color='blue', alpha=0.5)
    plt.plot(train_dates, train_pred, label='ADAM (Latih)', color='green')
    plt.plot(test_dates, test_close, label='Aktual (Uji)', color='green', alpha=0.5)
    plt.plot(test_dates, test_pred, label='ADAM (Uji)', color='cyan')
    plt.title(f'Prediksi Harga IHSG dengan ADAM - Fold {fold}')
    plt.xlabel('Tanggal')
    plt.ylabel('Harga Penutupan')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(f'ihsg_prediction_adam_fold_{fold}_glorot.png')
    plt.show()

    # Visualisasi kurva loss
    history = adam_history[fold-1]
    plt.figure(figsize=(10, 5))
    plt.plot(history['loss'], label='Loss Latih (ADAM)', color='green')
    plt.plot(history['val_loss'], label='Loss Uji (ADAM)', color='red')
    plt.title(f'Kurva Loss Pelatihan - ADAM (Fold {fold}, Glorot Init)')
    plt.xlabel('Epoch')
    plt.ylabel('Mean Squared Error')
    plt.legend()
    plt.grid(True)
    plt.savefig(f'ihsg_loss_curve_adam_fold_{fold}_glorot.png')
    plt.show()
# Out:
# === Validasi ADAM Fold 1 ===
# === Validasi ADAM Fold 2 ===
# === Validasi ADAM Fold 3 ===
# === Validasi ADAM Fold 4 ===

# %% [markdown]
# ## 11. Agregasi dan Simpan Hasil
# Mengagregasi metrik, menyimpan hasil, dan membuat visualisasi kesalahan prediksi.

# %%
# Gabungkan semua prediksi
all_predictions = []
for fold in range(N_SPLITS):
    gann_df = gann_predictions_per_fold[fold][['Fold', 'Date', 'Actual_Close', 'Predicted_GANN', 'Data']]
    gadam_df = gadam_predictions_per_fold[fold][['Predicted_GADAM']]
    adam_df = adam_predictions_per_fold[fold][['Predicted_ADAM']]
    fold_df = pd.concat([gann_df, gadam_df, adam_df], axis=1)
    all_predictions.append(fold_df)

# Agregasi metrik
metrics_final = pd.DataFrame()
for model_type, metrics in [('GANN', gann_metrics), ('GADAM', gadam_metrics), ('ADAM', adam_metrics)]:
    metrics_df = pd.DataFrame(metrics)
    avg_metrics = metrics_df.groupby('Data')[['RMSE', 'MAE', 'MAPE']].mean().reset_index()
    avg_metrics['Model'] = model_type
    metrics_final = pd.concat([metrics_final, avg_metrics], ignore_index=True)
metrics_final = metrics_final[['Model', 'Data', 'RMSE', 'MAE', 'MAPE']].round(2)

# Simpan metrik
metrics_final.to_csv('ihsg_metrics_cv_glorot.csv', index=False)

# Simpan semua prediksi
all_predictions_df = pd.concat(all_predictions, ignore_index=True)
all_predictions_df.to_csv('ihsg_predictions_per_fold_glorot.csv', index=False)

# Simpan prediksi fold terakhir
last_fold_df = all_predictions[-1]
pred_df = pd.DataFrame({
    'Date': last_fold_df['Date'],
    'Actual_Close': last_fold_df['Actual_Close'],
    'Predicted_GANN': last_fold_df['Predicted_GANN'],
    'Predicted_GADAM': last_fold_df['Predicted_GADAM'],
    'Predicted_ADAM': last_fold_df['Predicted_ADAM']
})
pred_df.to_csv('ihsg_predictions_cv_glorot.csv', index=False)

# Simpan bobot terbaik (GANN dan GADAM)
for model_type, best_weights in [('GANN', gann_best_weights), ('GADAM', gadam_best_weights)]:
    weights_df = []
    for fold, weights in enumerate(best_weights, 1):
        w1 = np.array(weights[:INPUT_DIM * HIDDEN_NEURONS]).reshape(INPUT_DIM, HIDDEN_NEURONS)
        b1 = np.array(weights[INPUT_DIM * HIDDEN_NEURONS:INPUT_DIM * HIDDEN_NEURONS + HIDDEN_NEURONS])
        w2 = np.array(weights[INPUT_DIM * HIDDEN_NEURONS + HIDDEN_NEURONS:INPUT_DIM * HIDDEN_NEURONS + 2 * HIDDEN_NEURONS]).reshape(HIDDEN_NEURONS, 1)
        b2 = np.array([weights[-1]])
        weights_df.append({
            'Fold': fold,
            'Input_to_Hidden': w1.tolist(),
            'Bias_to_Hidden': b1.tolist(),
            'Hidden_to_Output': w2.tolist(),
            'Bias_to_Output': b2.tolist()
        })
    weights_df = pd.DataFrame(weights_df)
    weights_df.to_csv(f'ihsg_best_weights_{model_type.lower()}_glorot.csv', index=False)

# Visualisasi kesalahan prediksi
for fold in range(1, N_SPLITS + 1):
    fold_df = all_predictions[fold-1]
    test_dates = fold_df[fold_df['Data'] == 'Uji']['Date'].values
    test_close = fold_df[fold_df['Data'] == 'Uji']['Actual_Close'].values
    for model_type in ['GANN', 'GADAM', 'ADAM']:
        pred_col = f'Predicted_{model_type}'
        error = test_close - fold_df[fold_df['Data'] == 'Uji'][pred_col].values

        plt.figure(figsize=(14, 6))
        plt.plot(test_dates, error, label=f'Kesalahan {model_type} (Aktual - Prediksi)', 
                 color='red' if model_type == 'GANN' else 'blue' if model_type == 'GADAM' else 'green', alpha=0.5)
        plt.axhline(0, color='black', linestyle='--')
        plt.title(f'Kesalahan Prediksi Harga IHSG (Fold {fold}, {model_type}, Glorot Init)')
        plt.xlabel('Tanggal')
        plt.ylabel('Kesalahan (Poin)')
        plt.legend()
        plt.grid(True)
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.savefig(f'ihsg_prediction_error_{model_type.lower()}_fold_{fold}_glorot.png')
        plt.show()

# Tampilkan hasil
print("\nPerbandingan Metrik Evaluasi (Rata-rata):")
print(metrics_final)
print(f"\nPerbandingan Nilai Aktual dan Prediksi (Fold {N_SPLITS}):")
print(pred_df.head(10))

print("\nMetrik evaluasi disimpan ke 'ihsg_metrics_cv_glorot.csv'")
print("Prediksi per fold disimpan ke 'ihsg_predictions_per_fold_glorot.csv'")
print("Prediksi fold terakhir disimpan ke 'ihsg_predictions_cv_glorot.csv'")
print("Model final disimpan di direktori 'models/'")
print("Bobot terbaik disimpan ke 'ihsg_best_weights_*.csv'")
# Out:
# Perbandingan Metrik Evaluasi (Rata-rata):
#    Model   Data    RMSE     MAE  MAPE
# 0   GANN  Latih   57.46   42.19  0.61
# 1   GANN    Uji   59.60   46.72  0.67
# 2  GADAM  Latih   54.94   41.27  0.60
# 3  GADAM    Uji   57.97   45.18  0.64
# 4   ADAM  Latih  128.15  104.21  1.49
# 5   ADAM    Uji  196.55  173.35  2.40
#
# Perbandingan Nilai Aktual dan Prediksi (Fold 4):
#         Date  Actual_Close  Predicted_GANN  Predicted_GADAM  Predicted_ADAM
# 0 2022-01-06       6653.35     6670.167969      6673.016113     6779.747070
# 1 2022-01-07       6701.32     6665.560059      6667.890625     6759.761719
# 2 2022-01-10       6691.12     6680.186035      6710.167969     6754.202148
# 3 2022-01-11       6647.97     6683.516113      6700.878906     6782.340820
# 4 2022-01-12       6647.06     6670.798828      6664.135742     6775.964844
# 5 2022-01-13       6658.36     6657.962891      6661.852539     6752.237793
# 6 2022-01-14       6693.40     6652.786621      6668.070801     6753.679199
# 7 2022-01-17       6645.05     6673.367188      6702.944824     6758.329102
# 8 2022-01-18       6614.06     6658.991699      6657.337891     6779.920898
# 9 2022-01-19       6591.98     6640.691895      6633.423340     6752.136230
#
# Metrik evaluasi disimpan ke 'ihsg_metrics_cv_glorot.csv'
# Prediksi per fold disimpan ke 'ihsg_predictions_per_fold_glorot.csv'
# Prediksi fold terakhir disimpan ke 'ihsg_predictions_cv_glorot.csv'
# Model final disimpan di direktori 'models/'
# Bobot terbaik disimpan ke 'ihsg_best_weights_*.csv'

# %% [markdown]
# ## 12. Visualisasi Perbandingan Metrik
# Membuat visualisasi perbandingan metrik untuk semua model.

# %%
for metric in ['RMSE', 'MAE', 'MAPE']:
    plt.figure(figsize=(8, 6))
    sns.barplot(data=metrics_final, x='Data', y=metric, hue='Model')
    plt.title(f'Perbandingan {metric} untuk GANN, GADAM, dan ADAM')
    plt.xlabel('Data')
    plt.ylabel(metric)
    plt.legend(title='Model')
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f'ihsg_metrics_comparison_{metric.lower()}.png')
    plt.show()
